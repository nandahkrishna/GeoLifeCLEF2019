# %%
# !ls
# Out:
#  ann_submission.h5			   'Plantnet trusted occurences.csv'
#  environmental_raster_glc.py		    plot.py
# 'Environmental rasters data'		   'Protocole Note.pdf'
#  extract_offline.py			    runkeras.py
#  extract_online_pytorch.py		    simpleann.ipynb
#  extract_sample.py			    submission.csv
# 'GeoLifeCLEF 2019_PL_trusted.csv'	   'Table of species & identifiers.csv'
# 'GeoLifeCLEF 2019_taxaName_glc19SpId.csv'  'Test set.csv'
# 'GeoLifeCLEF 2019_testSet.csv'		   'Train non-plant occurences'
# 'GLC 2018.csv'				    Untitled.ipynb
# 'Plantnet complete occurences'

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense,Dropout
from sklearn.preprocessing import OneHotEncoder
# Out:
# Using TensorFlow backend.

# %%
cls = Sequential()

# %%
df = pd.read_csv("size1_trusted.csv")

# %%
x = df.iloc[:,:80].values
y = df['glc19SpId'].iloc[:].values

# %%
enc = OneHotEncoder()
enc.fit(y.reshape(-1,1))
y = enc.fit_transform(y.reshape(-1,1)).toarray()
# Out:
# /home/praveen/anaconda3/envs/Tensorflow/lib/python3.5/site-packages/sklearn/preprocessing/_encoders.py:363: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /home/praveen/anaconda3/envs/Tensorflow/lib/python3.5/site-packages/sklearn/preprocessing/_encoders.py:363: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
l = enc.get_feature_names()
l = l.tolist()

# %%
f = []
for i in range(len(l)):
    f.append(l[i].split('_')[1].split('.')[0])

# %%
cls.add(Dense(256,activation='relu'))
cls.add(Dense(256,activation='relu'))
cls.add(Dropout(rate = 0.02))
cls.add(Dense(256,activation='relu'))
cls.add(Dense(256,activation='relu'))
cls.add(Dropout(rate = 0.02))
cls.add(Dense(256,activation='relu'))
cls.add(Dense(256,activation='relu'))
cls.add(Dense(1348,activation='softmax'))

# %%
cls.compile(optimizer = 'adam', loss='categorical_crossentropy', metrics = ['accuracy'])
cls.fit(x=x,y=y,epochs = 10)
# Out:
# Epoch 1/10
# 236533/236533 [==============================] - 81s 344us/step - loss: 16.1057 - acc: 7.6945e-04
# Epoch 2/10
# 236533/236533 [==============================] - 63s 268us/step - loss: 16.1056 - acc: 7.7368e-04
# Epoch 3/10
# 236533/236533 [==============================] - 63s 268us/step - loss: 16.1056 - acc: 7.7368e-04
# Epoch 4/10
# 236533/236533 [==============================] - 65s 274us/step - loss: 16.1056 - acc: 7.7368e-04
# Epoch 5/10
# 236533/236533 [==============================] - 65s 276us/step - loss: 16.1056 - acc: 7.7368e-04
# Epoch 6/10
# 236533/236533 [==============================] - 65s 274us/step - loss: 16.1056 - acc: 7.7368e-04
# Epoch 7/10
# 236533/236533 [==============================] - 65s 275us/step - loss: 16.1056 - acc: 7.7368e-04
# Epoch 8/10
# 236533/236533 [==============================] - 65s 275us/step - loss: 16.1056 - acc: 7.7368e-04
# Epoch 9/10
# 236533/236533 [==============================] - 65s 276us/step - loss: 16.1056 - acc: 7.7368e-04
# Epoch 10/10
# 236533/236533 [==============================] - 64s 271us/step - loss: 16.1056 - acc: 7.7368e-04

# %%
cls.save('ann_submission_size1.h5')

# %%
t = pd.read_csv('Test set.csv',sep=';')
t
# Out:
#        glc19TestOccId  Longitude   Latitude
# 0               14996   4.112181  44.145591
# 1               11890   4.025015  44.416906
# 2               16620   5.890941  43.391232
# 3                7598   6.958683  44.112405
# 4                2614   6.268597  43.384625
# 5                8344   5.942728  43.654716
# 6               24115   3.446611  43.741885
# 7               10729   4.796544  43.536242
# 8                5428   5.433145  44.036048
# 9                2636   2.464158  43.136189
# 10              17475   5.510949  43.529532
# 11              13604   5.163593  43.846884
# 12              20628   2.215651  42.914600
# 13               2148   2.747749  42.907509
# 14              15424   7.628787  44.042827
# 15               6332   3.732623  44.644241
# 16               9221   7.589037  44.097775
# 17              23491   4.816266  44.187820
# 18              11005   5.811062  43.702139
# 19               2852   6.290871  43.757182
# 20              24722   4.354666  43.711084
# 21              10061   3.661875  43.577920
# 22               9130   3.156265  44.625104
# 23              19134   6.832846  43.439430
# 24              16358   4.788508  44.203915
# 25                895   6.584260  43.309367
# 26              19549   5.300287  43.440280
# 27               2033   3.254450  44.570969
# 28              23054   5.779324  43.472465
# 29              13562   7.674784  44.065962
# ...               ...        ...        ...
# 24970            2114   4.534996  43.897414
# 24971           10194   5.642166  43.591818
# 24972            7692   3.715349  44.548105
# 24973           17653   3.938454  44.033371
# 24974           19966   3.042989  42.579351
# 24975            2575   4.658728  44.020763
# 24976           11934   2.963927  42.667010
# 24977           20720   4.695916  43.981350
# 24978             769   4.300802  43.865407
# 24979           16478   3.028349  42.490764
# 24980            5633   4.905585  43.370882
# 24981           23101   3.429149  44.527118
# 24982            9404   4.755826  43.550560
# 24983            4783   5.821772  43.295947
# 24984           22408   2.031373  42.496691
# 24985           15765   4.112181  44.145591
# 24986            4926   4.043957  44.124172
# 24987           15956   5.196805  43.428630
# 24988            4212   4.174054  43.896473
# 24989           23561   7.135809  43.814328
# 24990           24325   5.868744  43.471675
# 24991           18744   6.210964  43.234485
# 24992           19983   6.565490  43.456614
# 24993           10649   3.032003  42.487886
# 24994           11388   4.575028  43.992169
# 24995             820   5.527765  43.423329
# 24996           12016   7.081772  43.755047
# 24997           17875   4.078303  43.971570
# 24998           14846   3.447034  44.403321
# 24999           16745   7.563677  44.127514
#
# [25000 rows x 3 columns]

# %%
x_test = t.iloc[:,1:].values

# %%
x_test
# Out:
# array([[ 4.11218074, 44.14559079],
#        [ 4.02501499, 44.41690551],
#        [ 5.89094145, 43.3912319 ],
#        ...,
#        [ 4.07830266, 43.97156997],
#        [ 3.44703368, 44.40332105],
#        [ 7.56367662, 44.12751405]])

# %%
from keras.models import load_model
cls = load_model('ann_submission.h5')
y_pred = cls.predict(x_test)

# %%
ind = list(range(len(y_pred)))

# %%
res = pd.DataFrame(y_pred.tolist())

# %%
rem = pd.read_csv('praveen.csv',sep = ';')

# %%
rem = rem[rem['test']==True]

# %%
IDSel = rem['glc19SpId'].iloc[:].values.tolist()
for i in range(len(IDSel)):
    IDSel[i]=str(IDSel[i])

# %%
def selecttop30(i):
    global y_pred,IDsel,f
    s = pd.DataFrame(y_pred[i].reshape(-1,1),columns = ['pred'])
    s = pd.concat([s,pd.DataFrame(f,columns = ['classID'])],axis = 1)
    s = s[s['classID'].isin(IDSel)]
    s = s.sort_values(by = ['pred'],axis = 0,ascending = 0)
    s.reset_index(level=0, inplace=True)
    s.reset_index(level=0, inplace=True)
    s = s.drop(['index'],axis = 1)
    s = pd.DataFrame(s.iloc[:30,:].values.tolist(),columns = ['Rank','Probability','ClassID'])
    return s

# %%
result = pd.DataFrame()
for i in range(len(res)):
    temp = selecttop30(i)
    temp['glc19TestOccId']=t['glc19TestOccId'][i]
    result = pd.concat([result,temp],axis = 0)

# %%
r = result.copy()
r1 = r.copy()
r = pd.concat([r.drop(['ClassID'],axis  = 1),r1['ClassID']],axis = 1)
r = pd.concat([r.drop(['Rank'],axis  = 1),r1['Rank']],axis = 1)
r = pd.concat([r.drop(['Probability'],axis  = 1),r1['Probability']],axis = 1)
#r = r.drop(['Unnamed: 0'],axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-52f959807d95> in <module>()
#       4 r = pd.concat([r.drop(['Rank'],axis  = 1),r1['Rank']],axis = 1)
#       5 r = pd.concat([r.drop(['Probability'],axis  = 1),r1['Probability']],axis = 1)
# ----> 6 r = r.drop(['Unnamed: 0'],axis = 1)
#
# ~/anaconda3/envs/Tensorflow/lib/python3.5/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/envs/Tensorflow/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# ~/anaconda3/envs/Tensorflow/lib/python3.5/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# ~/anaconda3/envs/Tensorflow/lib/python3.5/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
r['Rank']+=1
r.to_csv('submission1.csv',sep = ';')

# %%
r
# Out:
#     glc19TestOccId ClassID  Rank  Probability
# 0            14996   30683     2     0.059030
# 1            14996   30123     3     0.022455
# 2            14996   33757     4     0.021840
# 3            14996   30849     5     0.021739
# 4            14996   30914     6     0.021296
# 5            14996   29989     7     0.018031
# 6            14996   29980     8     0.017892
# 7            14996   30415     9     0.017636
# 8            14996   30898    10     0.016144
# 9            14996   31097    11     0.015039
# 10           14996   29985    12     0.014227
# 11           14996   30494    13     0.013620
# 12           14996   30455    14     0.012358
# 13           14996   30148    15     0.010327
# 14           14996   34244    16     0.009802
# 15           14996   31967    17     0.008762
# 16           14996   30105    18     0.008434
# 17           14996   30307    19     0.008426
# 18           14996   30248    20     0.007809
# 19           14996   30505    21     0.006741
# 20           14996   30745    22     0.006419
# 21           14996   30048    23     0.006281
# 22           14996   32012    24     0.006079
# 23           14996   30185    25     0.006046
# 24           14996   31218    26     0.004894
# 25           14996   30069    27     0.004583
# 26           14996   31450    28     0.004472
# 27           14996   30055    29     0.004472
# 28           14996   31345    30     0.004279
# 29           14996   30084    31     0.004259
# ..             ...     ...   ...          ...
# 0            16745   33757     2     0.043188
# 1            16745   30683     3     0.032206
# 2            16745   30898     4     0.026606
# 3            16745   30123     5     0.018065
# 4            16745   30849     6     0.016562
# 5            16745   30914     7     0.015085
# 6            16745   29989     8     0.012150
# 7            16745   30494     9     0.011415
# 8            16745   29985    10     0.011009
# 9            16745   29980    11     0.010185
# 10           16745   34244    12     0.009230
# 11           16745   30723    13     0.008349
# 12           16745   30415    14     0.008101
# 13           16745   32012    15     0.007821
# 14           16745   31010    16     0.007332
# 15           16745   30102    17     0.007285
# 16           16745   31218    18     0.006726
# 17           16745   30148    19     0.006667
# 18           16745   31450    20     0.006186
# 19           16745   31292    21     0.006065
# 20           16745   30455    22     0.005902
# 21           16745   30084    23     0.005799
# 22           16745   32227    24     0.005662
# 23           16745   30509    25     0.005656
# 24           16745   30105    26     0.005547
# 25           16745   30248    27     0.005160
# 26           16745   30745    28     0.004778
# 27           16745   31097    29     0.004545
# 28           16745   34332    30     0.004086
# 29           16745   30697    31     0.003990
#
# [750000 rows x 4 columns]

# %%
s = set(r['ClassID'])
len(s)
# Out:
# 98

# %%
IDSel = set(rem['glc19SpId'].iloc[:].values.tolist())

# %%
for i in range(len(f)):
    f[i]=int(f[i])
    f = set(f)

# %%
len(f)
# Out:
# 1348

# %%
len(IDSel)
# Out:
# 844

# %%
len(set(IDSel-f))
# Out:
# 293

# %%
len(set(IDSel&f))
# Out:
# 551
